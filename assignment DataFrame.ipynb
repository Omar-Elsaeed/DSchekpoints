# %% [markdown]
# ## importing libraries

# %%
import os 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## importing data

# %%
Salaries = pd.read_csv('Salaries.csv')
Salaries
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#for process to know how to work on this data
#to find full information 
#################


Salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
#to know describtion about this data
######### 

Salaries.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
#Choose the colums to see the direct way to start analysis
########

Salaries[['JobTitle','BasePay','OvertimePay','OtherPay','TotalPay','TotalPayBenefits','Year']].describe()
# Out:
#              BasePay    OvertimePay       OtherPay       TotalPay  \
# count  148045.000000  148650.000000  148650.000000  148654.000000
# mean    66325.448841    5066.059886    3648.767297   74768.321972
# std     42764.635495   11454.380559    8056.601866   50517.005274
# min      -166.010000      -0.010000   -7058.590000    -618.130000
# 25%     33588.200000       0.000000       0.000000   36168.995000
# 50%     65007.450000       0.000000     811.270000   71426.610000
# 75%     94691.050000    4658.175000    4236.065000  105839.135000
# max    319275.010000  245131.880000  400184.250000  567595.430000
#
#        TotalPayBenefits           Year
# count     148654.000000  148654.000000
# mean       93692.554811    2012.522643
# std        62793.533483       1.117538
# min         -618.130000    2011.000000
# 25%        44065.650000    2012.000000
# 50%        92404.090000    2013.000000
# 75%       132876.450000    2014.000000
# max       567595.430000    2014.000000

# %% [markdown]
# ## preprocessing data

# %%
#To Know if eny value dublicated or not

Salaries['JobTitle'].value_counts()
# Out:
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: JobTitle, Length: 2159, dtype: int64

# %%
#To Know if eny value dublicated or not


Salaries['EmployeeName'].value_counts()
# Out:
# Kevin Lee                   13
# Richard Lee                 11
# Steven Lee                  11
# William Wong                11
# Stanley Lee                  9
#                             ..
# Jeffrey Skover               1
# Ken Dever                    1
# Kevin Whitfield              1
# Granville McCollough III     1
# Joe Lopez                    1
# Name: EmployeeName, Length: 110811, dtype: int64

# %%
#To Know if eny value dublicated or not


Salaries['BasePay'].value_counts()
# Out:
# 0.00        1298
# 54703.00     338
# 55026.00     297
# 48472.40     210
# 65448.00     153
#             ...
# 65402.73       1
# 68818.72       1
# 73810.54       1
# 56242.68       1
# 15.50          1
# Name: BasePay, Length: 109489, dtype: int64

# %%
#Cheking missed data
# We Found missed data in [[Benefits]] ,, [[status]],,[[Notes]]

Salaries.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
#to Know lenth of id and it's not dublicated 

len (Salaries['Id'].value_counts())
# Out:
# 148654

# %%
#Cheking dup data

Salaries.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### This Data Talking about payment based on jobtitle ####

# %% [markdown]
# # Analysis data

# %%
Salaries.sample(30)
# Out:
#             Id            EmployeeName                             JobTitle  \
# 12320    12321           GISELLE CASEY                       COURT REPORTER
# 21578    21579                SANDY NG                         SENIOR CLERK
# 38197    38198           Marila Aquino                     Registered Nurse
# 21583    21584            REBECA RAMOS  MENTAL HEALTH REHABILITATION WORKER
# 129575  129576           Sharon L Penn         Disease Control Investigator
# 57295    57296           James McGarty                       Asphalt Worker
# 101344  101345            John E Tursi                     Police Officer 3
# 124962  124963          William Gaitan               Administrative Analyst
# 113296  113297         Janet M Kosewic                     Registered Nurse
# 11983    11984            HERBERT WARD                     TRANSIT OPERATOR
# 124445  124446        Miu-Wa-Lori Chan                          Librarian 2
# ...

# %%
#Trying to show result on plot bar

Salaries['JobTitle'].value_counts().plot().bar('BasePay','TotalPayBenefits')
# Out:
# <BarContainer object of 1 artists>

# %%
Salaries
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#To know all pay after sum total pay and benefits

Salaries['Allpay'] = Salaries['TotalPay'] + Salaries['TotalPayBenefits']
Salaries
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
#To drop not important col

Salaries.drop('Status',axis=1)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
##### to see the ide's grather than 0

Salaries['Allpay'] > 0
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: Allpay, Length: 148654, dtype: bool

# %%
Salaries[['Allpay','TotalPayBenefits']] >0
# Out:
#         Allpay  TotalPayBenefits
# 0         True              True
# 1         True              True
# 2         True              True
# 3         True              True
# 4         True              True
# ...        ...               ...
# 148649   False             False
# 148650   False             False
# 148651   False             False
# 148652   False             False
# 148653   False             False
#
# [148654 rows x 2 columns]

# %%
#To know the id who is get the highest pay according on his jobtitle
 
Salaries[['Id','JobTitle','TotalPayBenefits','Allpay']]
# Out:
#             Id                                        JobTitle  \
# 0            1  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            2                 CAPTAIN III (POLICE DEPARTMENT)
# 2            3                 CAPTAIN III (POLICE DEPARTMENT)
# 3            4            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4            5    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...        ...                                             ...
# 148649  148650                                       Custodian
# 148650  148651                                    Not provided
# 148651  148652                                    Not provided
# 148652  148653                                    Not provided
# 148653  148654                      Counselor, Log Cabin Ranch
#
#         TotalPayBenefits      Allpay
# 0              567595.43  1135190.86
# 1              538909.28  1077818.56
# 2              335279.91   670559.82
# 3              332343.61   664687.22
# ...

# %%
## I need to get the most jobtitle pay in this data to know
## the sequnce of first place and so once so forth###########

# %%
Salaries['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object
